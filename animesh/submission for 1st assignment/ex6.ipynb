# %%
import numpy as np
import matplotlib as plt 
import pandas as pd

# %%
df = pd.DataFrame({'Name' : ['Alice' , 'Bob' , 'Charlie' , 'Diana' , 'Ethan'],
                    'Age' : [28 , 34 , 25 , 42 , 30],
                    'Salary' : [70000 , 80000 , 50000 , 110000 , 75000]})

print(df)
# Out:
#       Name  Age  Salary
# 0    Alice   28   70000
# 1      Bob   34   80000
# 2  Charlie   25   50000
# 3    Diana   42  110000
# 4    Ethan   30   75000

# %%
df['Tax'] = (20/100) * df['Salary']

print(df)
# Out:
#       Name  Age  Salary      Tax
# 0    Alice   28   70000  14000.0
# 1      Bob   34   80000  16000.0
# 2  Charlie   25   50000  10000.0
# 3    Diana   42  110000  22000.0
# 4    Ethan   30   75000  15000.0

# %%
df1 = df[df['Age'] >= 30] 
df2 = df[df['Age'] < 30]
print( df1 )
# Out:
#     Name  Age  Salary      Tax
# 1    Bob   34   80000  16000.0
# 3  Diana   42  110000  22000.0
# 4  Ethan   30   75000  15000.0

# %%
print( df2 )

print( df2['Salary'].mean() )
# Out:
#       Name  Age  Salary      Tax
# 0    Alice   28   70000  14000.0
# 2  Charlie   25   50000  10000.0
# 60000.0

# %%
df.sort_values( by='Salary' , ascending=False , inplace= True )

print( df )
# Out:
#       Name  Age  Salary      Tax
# 3    Diana   42  110000  22000.0
# 1      Bob   34   80000  16000.0
# 4    Ethan   30   75000  15000.0
# 0    Alice   28   70000  14000.0
# 2  Charlie   25   50000  10000.0
